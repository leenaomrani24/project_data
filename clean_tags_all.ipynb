# %%
import pandas as pd

# %%
df= pd.read_json('/Users/leenaomrani/Desktop/final-project/data_jobs_france/all_data_France_tags.json')
df1=pd.read_json('/Users/leenaomrani/Desktop/final-project/jobs_IA_france/all_IA_France_tags.json')
df2=pd.read_json('/Users/leenaomrani/Desktop/final-project/jobs_intelligence_artficielle_france/jobs_intelligence_tags.json')
df3=pd.read_json('/Users/leenaomrani/Desktop/final-project/jobs_science_des_données_france/jobs_science_tags.json')

# %%
merged_df = pd.concat([df, df1,df2,df3], axis=0)

# %%
df= merged_df

# %%
df

# %%
import re

# %%
df['tags_secteur'] = [''.join(map(str, d)) for d in df['tags_secteur']]
df
# Out:
#                                               url_offre  \
# 0     https://www.hellowork.com/fr-fr/emplois/303120...
# 1     https://www.hellowork.com/fr-fr/emplois/316369...
# 2     https://www.hellowork.com/fr-fr/emplois/341842...
# 3     https://www.hellowork.com/fr-fr/emplois/341918...
# 4     https://www.hellowork.com/fr-fr/emplois/341710...
# ...                                                 ...
# 1155  https://www.hellowork.com/fr-fr/emplois/336950...
# 1156  https://www.hellowork.com/fr-fr/emplois/338608...
# 1157  https://www.hellowork.com/fr-fr/emplois/324048...
# 1158  https://www.hellowork.com/fr-fr/emplois/330759...
# 1159  https://www.hellowork.com/fr-fr/emplois/348199...
#
#                                            tags_secteur  \
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...
# 1155  \n                Industrie Pharmaceutique • B...
# 1156  \n                Service public des collectiv...
# ...

# %%
df['tags_secteur'] = df['tags_secteur'].str.replace('\n',' ')
df
# Out:
#                                               url_offre  \
# 0     https://www.hellowork.com/fr-fr/emplois/303120...
# 1     https://www.hellowork.com/fr-fr/emplois/316369...
# 2     https://www.hellowork.com/fr-fr/emplois/341842...
# 3     https://www.hellowork.com/fr-fr/emplois/341918...
# 4     https://www.hellowork.com/fr-fr/emplois/341710...
# ...                                                 ...
# 1155  https://www.hellowork.com/fr-fr/emplois/336950...
# 1156  https://www.hellowork.com/fr-fr/emplois/338608...
# 1157  https://www.hellowork.com/fr-fr/emplois/324048...
# 1158  https://www.hellowork.com/fr-fr/emplois/330759...
# 1159  https://www.hellowork.com/fr-fr/emplois/348199...
#
#                                            tags_secteur  \
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...
# 1155                   Industrie Pharmaceutique • Bi...
# 1156                   Service public des collectivi...
# ...

# %%
# voir tag_secteur2
def count_empty_lists(lst):
    if lst == []:
        return 1
    else:
        return 0

# apply the function to the 'tag_secteur 2' column and sum the results
num_empty_lists = df['tags_secteur2'].apply(count_empty_lists).sum()

# print the number of empty lists
print("Number of empty lists:", num_empty_lists)
# Out:
# Number of empty lists: 12716

# %%
df1=df.drop('tags_secteur2',axis=1)

# %%
df1
# Out:
#                                               url_offre  \
# 0     https://www.hellowork.com/fr-fr/emplois/303120...
# 1     https://www.hellowork.com/fr-fr/emplois/316369...
# 2     https://www.hellowork.com/fr-fr/emplois/341842...
# 3     https://www.hellowork.com/fr-fr/emplois/341918...
# 4     https://www.hellowork.com/fr-fr/emplois/341710...
# ...                                                 ...
# 1155  https://www.hellowork.com/fr-fr/emplois/336950...
# 1156  https://www.hellowork.com/fr-fr/emplois/338608...
# 1157  https://www.hellowork.com/fr-fr/emplois/324048...
# 1158  https://www.hellowork.com/fr-fr/emplois/330759...
# 1159  https://www.hellowork.com/fr-fr/emplois/348199...
#
#                                            tags_secteur  \
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...
# 1155                   Industrie Pharmaceutique • Bi...
# 1156                   Service public des collectivi...
# ...

# %%
df1['tags_education2'] = [''.join(map(str, d)) for d in df1['tags_education2']]
df1
# Out:
#                                               url_offre  \
# 0     https://www.hellowork.com/fr-fr/emplois/303120...
# 1     https://www.hellowork.com/fr-fr/emplois/316369...
# 2     https://www.hellowork.com/fr-fr/emplois/341842...
# 3     https://www.hellowork.com/fr-fr/emplois/341918...
# 4     https://www.hellowork.com/fr-fr/emplois/341710...
# ...                                                 ...
# 1155  https://www.hellowork.com/fr-fr/emplois/336950...
# 1156  https://www.hellowork.com/fr-fr/emplois/338608...
# 1157  https://www.hellowork.com/fr-fr/emplois/324048...
# 1158  https://www.hellowork.com/fr-fr/emplois/330759...
# 1159  https://www.hellowork.com/fr-fr/emplois/348199...
#
#                                            tags_secteur  \
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...
# 1155                   Industrie Pharmaceutique • Bi...
# 1156                   Service public des collectivi...
# ...

# %%
df1['tags_education2'] = df1['tags_education2'].str.replace('\n',' ')
df1
# Out:
#                                               url_offre  \
# 0     https://www.hellowork.com/fr-fr/emplois/303120...
# 1     https://www.hellowork.com/fr-fr/emplois/316369...
# 2     https://www.hellowork.com/fr-fr/emplois/341842...
# 3     https://www.hellowork.com/fr-fr/emplois/341918...
# 4     https://www.hellowork.com/fr-fr/emplois/341710...
# ...                                                 ...
# 1155  https://www.hellowork.com/fr-fr/emplois/336950...
# 1156  https://www.hellowork.com/fr-fr/emplois/338608...
# 1157  https://www.hellowork.com/fr-fr/emplois/324048...
# 1158  https://www.hellowork.com/fr-fr/emplois/330759...
# 1159  https://www.hellowork.com/fr-fr/emplois/348199...
#
#                                            tags_secteur  \
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...
# 1155                   Industrie Pharmaceutique • Bi...
# 1156                   Service public des collectivi...
# ...

# %%
num_empty_lists=df1['tags_secteur'].isna().sum()

# %%
num_empty_lists
# Out:
# 0

# %%
df1['tags_secteur'] = df1.apply(lambda row: row['tags_secteur1'] if row['tags_secteur'] == '' else row['tags_secteur'], axis=1)

# %%
df1
# Out:
#                                               url_offre  \
# 0     https://www.hellowork.com/fr-fr/emplois/303120...
# 1     https://www.hellowork.com/fr-fr/emplois/316369...
# 2     https://www.hellowork.com/fr-fr/emplois/341842...
# 3     https://www.hellowork.com/fr-fr/emplois/341918...
# 4     https://www.hellowork.com/fr-fr/emplois/341710...
# ...                                                 ...
# 4                    Services aux Entreprises     ...
# 6
# 8
# 10                   Secteur informatique • ESN   ...
# 11
# 12                   Services aux Entreprises     ...
# 14
# 15                   Services aux Entreprises     ...
# 16
# 17
#
# ...

# %%
def extract_id_offre(url_offre):
    match = re.search(r'/(\d+)\.html', url_offre)
    if match:
        return match.group(1)
    else:
        return None

# apply the function to the 'url' column and create a new 'number' column
df1['id_offre'] = df1['url_offre'].apply(extract_id_offre)

# print the resulting DataFrame
print(df1)
# Out:
#                                               url_offre  \
# 0     https://www.hellowork.com/fr-fr/emplois/303120...
# 1     https://www.hellowork.com/fr-fr/emplois/316369...
# 2     https://www.hellowork.com/fr-fr/emplois/341842...
# 3     https://www.hellowork.com/fr-fr/emplois/341918...
# 4     https://www.hellowork.com/fr-fr/emplois/341710...
# ...                                                 ...
# 1155  https://www.hellowork.com/fr-fr/emplois/336950...
# 1156  https://www.hellowork.com/fr-fr/emplois/338608...
# 1157  https://www.hellowork.com/fr-fr/emplois/324048...
# 1158  https://www.hellowork.com/fr-fr/emplois/330759...
# 1159  https://www.hellowork.com/fr-fr/emplois/348199...
#
#                                            tags_secteur  \
# 0                      Secteur informatique • ESN   ...
# 1
# 2                      Secteur informatique • ESN   ...
# 3                      Secteur informatique • ESN   ...
# 4                      Services aux Entreprises     ...
# ...

# %%
df=df1.drop_duplicates(keep='last')
print(df)
# Out:
#                                               url_offre  \
# 4     https://www.hellowork.com/fr-fr/emplois/341710...
# 6     https://www.hellowork.com/fr-fr/emplois/342976...
# 8     https://www.hellowork.com/fr-fr/emplois/342231...
# 10    https://www.hellowork.com/fr-fr/emplois/303033...
# 11    https://www.hellowork.com/fr-fr/emplois/313242...
# ...                                                 ...
# 1155  https://www.hellowork.com/fr-fr/emplois/336950...
# 1156  https://www.hellowork.com/fr-fr/emplois/338608...
# 1157  https://www.hellowork.com/fr-fr/emplois/324048...
# 1158  https://www.hellowork.com/fr-fr/emplois/330759...
# 1159  https://www.hellowork.com/fr-fr/emplois/348199...
#
#                                            tags_secteur  \
# 4                      Services aux Entreprises     ...
# 6
# 8
# 10                     Secteur informatique • ESN   ...
# 11
# ...                                                 ...
# ...

# %%
df
# Out:
#                                               url_offre  \
# 4     https://www.hellowork.com/fr-fr/emplois/341710...
# 6     https://www.hellowork.com/fr-fr/emplois/342976...
# 8     https://www.hellowork.com/fr-fr/emplois/342231...
# 10    https://www.hellowork.com/fr-fr/emplois/303033...
# 11    https://www.hellowork.com/fr-fr/emplois/313242...
# ...                                                 ...
# 1155  https://www.hellowork.com/fr-fr/emplois/336950...
# 1156  https://www.hellowork.com/fr-fr/emplois/338608...
# 1157  https://www.hellowork.com/fr-fr/emplois/324048...
# 1158  https://www.hellowork.com/fr-fr/emplois/330759...
# 1159  https://www.hellowork.com/fr-fr/emplois/348199...
#
#                                            tags_secteur  \
# 4                      Services aux Entreprises     ...
# 6
# 8
# 10                     Secteur informatique • ESN   ...
# 11
# ...                                                 ...
# ...

# %%
df
# Out:
#                                               url_offre  \
# 4     https://www.hellowork.com/fr-fr/emplois/341710...
# 6     https://www.hellowork.com/fr-fr/emplois/342976...
# 8     https://www.hellowork.com/fr-fr/emplois/342231...
# 10    https://www.hellowork.com/fr-fr/emplois/303033...
# 11    https://www.hellowork.com/fr-fr/emplois/313242...
# ...                                                 ...
# 1155  https://www.hellowork.com/fr-fr/emplois/336950...
# 1156  https://www.hellowork.com/fr-fr/emplois/338608...
# 1157  https://www.hellowork.com/fr-fr/emplois/324048...
# 1158  https://www.hellowork.com/fr-fr/emplois/330759...
# 1159  https://www.hellowork.com/fr-fr/emplois/348199...
#
#                                            tags_secteur  \
# 4                      Services aux Entreprises     ...
# 6
# 8
# 10                     Secteur informatique • ESN   ...
# 11
# ...                                                 ...
# ...

# %%
df['tags_education'] = df['tags_education'].replace('[^Bac\+\d]', '', regex=True)
df['tags_education2'] = df['tags_education2'].replace('[^Bac\+\d]', '', regex=True)
# Out:
# /var/folders/qn/mtl559_57tn77j5y4wb_w49c0000gn/T/ipykernel_16820/3279835769.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags_education'] = df['tags_education'].replace('[^Bac\+\d]', '', regex=True)
# /var/folders/qn/mtl559_57tn77j5y4wb_w49c0000gn/T/ipykernel_16820/3279835769.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags_education2'] = df['tags_education2'].replace('[^Bac\+\d]', '', regex=True)

# %%
df['tags_education'] = df['tags_education'].fillna('') + ' ' + df['tags_education2'].fillna('')
# Out:
# /var/folders/qn/mtl559_57tn77j5y4wb_w49c0000gn/T/ipykernel_16820/2580809721.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags_education'] = df['tags_education'].fillna('') + ' ' + df['tags_education2'].fillna('')

# %%
df3=df.drop('tags_education2',axis=1)

# %%
df4.head(20)
# Out:
#                                             url_offre  \
# 4   https://www.hellowork.com/fr-fr/emplois/341710...
# 6   https://www.hellowork.com/fr-fr/emplois/342976...
# 8   https://www.hellowork.com/fr-fr/emplois/342231...
# 10  https://www.hellowork.com/fr-fr/emplois/303033...
# 11  https://www.hellowork.com/fr-fr/emplois/313242...
# 12  https://www.hellowork.com/fr-fr/emplois/341312...
# 14  https://www.hellowork.com/fr-fr/emplois/209572...
# 15  https://www.hellowork.com/fr-fr/emplois/340359...
# 16  https://www.hellowork.com/fr-fr/emplois/198988...
# 17  https://www.hellowork.com/fr-fr/emplois/268859...
# 19  https://www.hellowork.com/fr-fr/emplois/314610...
# 21  https://www.hellowork.com/fr-fr/emplois/341710...
# 22  https://www.hellowork.com/fr-fr/emplois/340570...
# 24  https://www.hellowork.com/fr-fr/emplois/329119...
# 25  https://www.hellowork.com/fr-fr/emplois/328976...
# 26  https://www.hellowork.com/fr-fr/emplois/340268...
# ...

# %%
df4=df3.drop('tags_secteur1',axis=1)

# %%
df4.to_csv('/Users/leenaomrani/Desktop/final-project/tags_jobs_france.csv')

# %%
df3['tags_education'] = df3['tags_education'].str.replace('Bac\+', 'Bac+ ', regex=True)

# %%
num_empty_rows = df['tags_secteur'].isnull().sum()

# %%
num_empty_rows
# Out:
# 0
